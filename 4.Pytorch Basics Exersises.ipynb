# %%
import numpy as np, torch

# %%
torch.manual_seed(42)
np.random.seed(42)

# %%
arr = np.random.randint(0,5,6)
arr
# Out:
# array([3, 4, 2, 4, 4, 1])

# %%
x = torch.tensor(arr)
x
# Out:
# tensor([3, 4, 2, 4, 4, 1])

# %%
x.type(torch.int64)
x.dtype
# Out:
# torch.int64

# %%
x = x.reshape(3,2)
x
# Out:
# tensor([[3, 4],
#         [2, 4],
#         [4, 1]])

# %%
x[:,1:]
# Out:
# tensor([[4],
#         [4],
#         [1]])

# %%
x.pow(2)
# Out:
# tensor([[ 9, 16],
#         [ 4, 16],
#         [16,  1]])

# %%
y = torch.randint(0,5,(x.shape[1],4))
y
# Out:
# tensor([[2, 2, 1, 4],
#         [1, 0, 0, 4]])

# %%
x.mm(y)
# Out:
# tensor([[10,  6,  3, 28],
#         [ 8,  4,  2, 24],
#         [ 9,  8,  4, 20]])
